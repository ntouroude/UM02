# %%
# Pandas for managing datasets
import pandas as pd

# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns


# Read dataset
df = pd.read_csv('D:\\Etudes\\UTC\\GSU05\\UM02\\Communities network\\UTSEUS-anjuke-real-estate.csv', index_col=0)

df['subset'] = np.random.uniform(0, 1, len(df)) <= .01
df = df[df['subset']==True]
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-731b6d16e2c0> in <module>
#      13 df = pd.read_csv('D:\\Etudes\\UTC\\GSU05\\UM02\\Communities network\\UTSEUS-anjuke-real-estate.csv', index_col=0)
#      14
# ---> 15 df['subset'] = np.random.uniform(0, 1, len(df)) <= .01
#      16 df = df[df['subset']==True]
#      17 len(df)
#
# NameError: name 'np' is not defined

# %%
sns.set()
# Display first 5 observations
df.head()

# Recommended way
sns.lmplot(x='longitude', y='price', data=df)

# Alternative way
# sns.lmplot(x=df.Attack, y=df.Defense)

# %%
# Scatterplot arguments
sns.lmplot(x='longitude', y='price', data=df,
           fit_reg=False, # No regression line
           hue='district')   # Color by evolution stage

# %%
# Plot using Seaborn
sns.lmplot(x='longitude', y='price', data=df,
           fit_reg=False, 
           hue='district')
 
# Tweak using Matplotlib
plt.ylim(0, None)
plt.xlim(0, None)

# %%
# Boxplot
sns.boxplot(data=df)

# %%
# Pre-format DataFrame
stats_df = df.drop(['price','onesquaremeter','surface'], axis=1)
 
# New boxplot using stats_df
sns.boxplot(data=stats_df)

# %%
# Set theme
sns.set_style('whitegrid')

plt.figure(figsize=(15,10))
 
# Violin plot
sns.violinplot(x='district', y='price', data=df)
plt.yscale('log')

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
# Violin plot with Pokemon color palette
plt.figure(figsize=(15,10))
sns.violinplot(x='district', y='price', data=df, 
               palette=pkmn_type_colors) # Set color palette
plt.yscale('log')

# %%
# Swarm plot with Pokemon color palette

sns.swarmplot(x='district', y='price', data=df[:1000], 
              palette=pkmn_type_colors)
plt.yscale('log')

# %%
# Set figure size with matplotlib
plt.figure(figsize=(10,6))
 
# Create plot
sns.violinplot(x='district',
               y='price', 
               data=df, 
               inner=None, # Remove the bars inside the violins
               palette=pkmn_type_colors)
 
sns.swarmplot(x='district', 
              y='price', 
              data=df, 
              color='k', # Make points black
              alpha=0.7) # and slightly transparent
 
# Set title with matplotlib
plt.title('oooodjadja')
